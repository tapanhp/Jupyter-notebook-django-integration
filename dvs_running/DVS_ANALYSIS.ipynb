# %%
# Define all the parameters that will be used by any cell in the future
PLOT_HIST_SIZE = 100
# this can be bar
PLOT_KIND = "box"

# %% [markdown]
# ### Import all the necessary libraries

# %%
import seaborn as sns
import numpy as np

# %% [markdown]
# ### Define functions to execute

# %%
def plotHist(PLOT_HIST_SIZE):
    x = np.random.normal(size = PLOT_HIST_SIZE)
    return sns.distplot(x)

# call function...

# %%
def bar_box():
    tips = sns.load_dataset("tips")
    figure =  sns.catplot(x="day", y="total_bill", kind= PLOT_KIND, data=tips)
    return figure.fig

# %%
bar_box()
